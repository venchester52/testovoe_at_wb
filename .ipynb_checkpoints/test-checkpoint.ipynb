# %%
print('Hello, world')
# Out:
# Hello, world

# %%
2+5
# Out:
# 7

# %%
import numpy as np
a = np.array([1, 2, 3, 4, 5])
b = np.array([[1, 2], [3, 4], [5, 6], [7, 8]])

# %%
print(f"a[0] = {a[0]}"
# Out:
#   Cell In[5], line 1
#     print(f"a[0] = {a[0]}"
#                           ^
# SyntaxError: incomplete input

# %%
print(print(f"a[0] = {a[0]}"))
# Out:
# a[0] = 1
# None

# %%
print(f"b[0] = {b[0]}")
# Out:
# b[0] = [1 2]
